# %% [markdown]
# <a href="https://colab.research.google.com/github/davidisinta/AI/blob/main/law_llms_p2_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

# Regex to match case names (start of a case)
case_name_pattern = re.compile(r'^[A-Z][a-zA-Z.\- ]+ v\. [A-Z][a-zA-Z.\- ]+')

# Read file
file_path = "combined-text.txt"


cases = []
cases_headers = []
current_case = []
blank_line_count = 0

line_num = 0
page = int(0)

with open(file_path, "r", encoding="utf-8") as file:
    for line in file:
        line_num += 1
        page = int(line_num / 10)
        if line.strip() == "":  # Blank line detected
            blank_line_count += 1
            continue

        if blank_line_count >= 2 and case_name_pattern.match(line) or line_num == 1:  # New case starts
            #get rid of prev case
            cases.append("\n".join(current_case))
            current_case = []
            current_case.append(line.strip())  # Start capturing new case
            cases_headers.append(f"{line.strip()}")
        else:  # Continue capturing case content
            current_case.append(line.strip())

        blank_line_count = 0  # Reset blank line counter


# Add last case if file doesn't end with a blank line
if current_case:
    cases.append("\n".join(current_case))

# Print extracted cases and total count
# for case in cases:
#     print(case)
#     print("=" * 80)  # Separator for readability

for case in cases_headers:
    print(case)
    print("=" * 80)  # Separator for readability


print(f"\nTotal cases extracted: {len(cases)}")
# Out:
# Burns v. McGraw-Hill Broadcasting Co., Inc., 9 Media L. Rep. (BNA) 1257 (Colo. 1983)
# ================================================================================
# Garden v. Parfumerie Rigaud, Inc., 151 Misc. 692 (N.Y. Sup. Ct. 1933)
# ================================================================================
# Gautier v. Pro-Football, Inc., 107 N.E.2d 485 (NY 1952)
# ================================================================================
# Belluomo v. Kake TV & Radio, Inc., 596 P.2d 832 (Kan. Ct. App. 1979)
# ================================================================================
# Nobles v. Cartwright, 659 N.E.2d 1064 (Ind. Ct. App. 1995)
# ================================================================================
# Passalacqua v. Naviant, Inc., 844 So. 2d 792 (Fla. Dist. Ct. App. 2003)
# ================================================================================
# McGough v. Nalco Co., 496 F. Supp. 2d 729 (N.D.W. Va. 2007)
# ================================================================================
# National Abortion Federation v. Center for Medical Progress, 926 F.3d 534 (9th Cir. 2019)
# ================================================================================
# Anonsen v. Donahue, 857 S.W.2d 700 (Tex. App. 1993)
# ================================================================================
# Kenol v. Nelson, 181 A.D.2d 863 (N.Y. App. Div. 1992)
# ================================================================================
# Keyzer v. Amerlink, Ltd., 654 S.E.2d 833 (N.C. Ct. App. 2008)
# ================================================================================
# Miller v. Brooks, 47 S.E. 646 (Ga. 1904)
# ================================================================================
# Miami Herald Pub. Co. v. Ane, 10 Media L. Rep. (BNA) 2383 (Fla. 1984)
# ================================================================================
# MILE MARKER INC. v. Petersen Publishing, LLC, 811 So. 2d 841 (Fla. Dist. Ct. App. 2002)
# ================================================================================
# Della-Donna v. Gore Newspapers Co., 489 So. 2d 72 (Fla. Dist. Ct. App. 1986)
# ================================================================================
# Dockery v. Florida Democratic Party, 799 So. 2d 291 (Fla. Dist. Ct. App. 2001)
# ================================================================================
# Silvester v. American Broadcasting Companies, Inc., 650 F. Supp. 766 (S.D. Fla. 1986)
# ================================================================================
# Gubarev v. Buzzfeed, Inc., 365 F. Supp. 3d 1250 (S.D. Fla. 2019)
# ================================================================================
# Saro Corp. v. Waterman Broadcasting Corp., 595 So. 2d 87 (Fla. Dist. Ct. App. 1992)
# ================================================================================
# From v. Tallahassee Democrat, Inc., 7 Media L. Rep. (BNA) 1811 (Fla. Dist. Ct. App. 1981)
# ================================================================================
# Uranga v. Federated Publications, Inc., 67 P.3d 29 (Idaho 2003)
# ================================================================================
# Steele v. Spokesman-Review, 61 P.3d 606 (Idaho 2002)
# ================================================================================
# State v. PENTICO, 265 P.3d 519 (Idaho Ct. App. 2011)
# ================================================================================
# Keyzer v. Amerlink, Ltd., 654 S.E.2d 833 (N.C. Ct. App. 2008)
# ================================================================================
# Broughton v. McClatchy Newspapers, Inc., 588 S.E.2d 20 (N.C. Ct. App. 2003)
# ================================================================================
# Magenis v. Fisher Broadcasting, Inc., 798 P.2d 1106 (Or. Ct. App. 1990)
# ================================================================================
# State v. Knobel, 777 P.2d 985 (Or. Ct. App. 1989)
# ================================================================================
# Mark v. Seattle Times, 635 P.2d 1081 (Wash. 1981)
# ================================================================================
# Phillips v. KIRO-TV, Inc., 817 F. Supp. 2d 1317 (W.D. Wash. 2011)
# ================================================================================
# Gonzaga University v. Doe, 536 U.S. 273
# ================================================================================
# Nieves v. Home Box Office, Inc., 30 A.D.3d 1143 (N.Y. App. Div. 2006)
# ================================================================================
# Reesman v. Highfill, 965 P.2d 1030 (Or. 1998)
# ================================================================================
# Marleau v. Truck Insurance Exchange, 37 P.3d 148 (Or. 2001)
# ================================================================================
# Tollefson v. Price, 430 P.2d 990 (Or. 1967)
# ================================================================================
# Dean v. Guard Publishing Co., 744 P.2d 1296 (Or. Ct. App. 1987)
# ================================================================================
# Robillard v. Opal Labs, Inc., 337 F. Supp. 3d 962 (D. Or. 2018)
# ================================================================================
# Magenis v. Fisher Broadcasting, Inc., 798 P.2d 1106 (Or. Ct. App. 1990)
# ================================================================================
# Miller v. American Sports Co., Inc., 467 N.W.2d 653 (Neb. 1991)
# ================================================================================
# Elbert v. Young, 312 Neb. 58 (Neb. 2022)
# ================================================================================
# Baxter Berry v. National Broadcasting Company, Inc., 480 F.2d 428 (8th Cir. 1973)
# ================================================================================
# New York Times Co. v. Sullivan, 376 U.S. 254
# ================================================================================
# McKinney v. Okoye, S-13-155 (Neb. 2014)
# ================================================================================
# Kaiser v. Western R/C Flyers, Inc., 477 N.W.2d 557 (Neb. 1991)
# ================================================================================
# Turner v. Welliver, 411 N.W.2d 298 (Neb. 1987)
# ================================================================================
# Moats v. Republican Party of Nebraska, 565 U.S. 882
# ================================================================================
# Funk v. Lincoln-Lancaster Cty. Crime Stoppers, 885 N.W.2d 1 (Neb. 2016)
# ================================================================================
# State v. Biernacki, 465 N.W.2d 732 (Neb. 1991)
# ================================================================================
# State v. Rudnick, 341 P.3d 211 (Or. Ct. App. 2014)
# ================================================================================
# Michael T. v. Crouch, 344 F. Supp. 3d 856 ( 2018)
# ================================================================================
# Howell v. New York Post Co., 81 N.Y.2d 115 (NY 1993)
# ================================================================================
# Beverley v. WOMEN'S MED CTR., 78 N.Y.2d 745 (NY 1991)
# ================================================================================
# Thompson v. Close-Up, Inc., 277 A.D.2d 848 (N.Y. App. Div. 1950)
# ================================================================================
# Messenger v. Gruner + Jahr Printing & Publishing, 727 N.E.2d 549 (NY 2000)
# ================================================================================
# Commonwealth v. Alleyne, 405 N.E.2d 171 (Mass. App. Ct. 1980)
# ================================================================================
# Jackson v. Commonwealth, 287 S.W. 17 (Ky. Ct. App. 1926)
# ================================================================================
# Commonwealth v. Hyde, 88 Mass. App. Ct. 761 (Mass. App. Ct. 2015)
# ================================================================================
# Project Veritas Action Fund v. Rollins, 19-1586P (1st Cir. 2020)
# ================================================================================
# Martin v. Rollins, Inc., 231 S.E.2d 751 (Ga. 1977)
# ================================================================================
# Bartnicki v. Vopper, 532 U.S. 514
# ================================================================================
# Ayash v. Dana-Farber Cancer Institute, 443 Mass. 367 (Mass. 2005)
# ================================================================================
# Ferrell v. Southern Nevada Off-Road Enthusiasts, Ltd., 147 Cal. App. 3d 309 (Cal. Ct. App. 1983)
# ================================================================================
# Hohe v. San Diego Unified School District, 224 Cal. App. 3d 1559 (Cal. Ct. App. 1990)
# ================================================================================
# Johnston v. Weil, 946 N.E.2d 329 (Ill. 2011)
# ================================================================================
# Facenda v. N.F.L. Films, Inc., 542 F.3d 1007 (3rd Cir. 2008)
# ================================================================================
# Ahn v. Midway Manufacturing Co., 965 F. Supp. 1134 (N.D. Ill. 1997)
# ================================================================================
# Kyser-Smith v. Upscale Communications, Inc., 873 F. Supp. 1519 (M.D. Ala. 1995)
# ================================================================================
# UNIVISION COMMUNICATIONS INC. v. CARLOS ENRIQUE LUNA LAM, 22-1790 (Fla. Dist. Ct. App. 2022)
# ================================================================================
# Powers v. United States, 223 U.S. 303
# ================================================================================
# Michael B. Price v. Time, Inc., 425 F.3d 1292 (11th Cir. 2005)
# ================================================================================
# Cooper v. Long, 244 P. 167 (Okla. 1926)
# ================================================================================
# Pinkard v. Johnson, 118 F.R.D. 517 (M.D. Ala. 1987)
# ================================================================================
# Capers v. State, 678 So. 2d 330 (Fla. 1996)
# ================================================================================
# Wilson v. Interlake Steel Co., 649 P.2d 922 (Cal. 1982)
# ================================================================================
# Ralphs Grocery Co. v. Victory Consultants, Inc., D070804A (Cal. Ct. App. 2018)
# ================================================================================
# Denver Publishing Co. v. Bueno, 54 P.3d 893 (Colo. 2002)
# ================================================================================
# Doe v. High-Tech Institute, Inc., 972 P.2d 1060 (Colo. Ct. App. 1998)
# ================================================================================
# Quigley v. Rosenthal, 427 F.3d 1232 (10th Cir. 2005)
# ================================================================================
# People v. Morton, 41 Cal. 2d 536 (Cal. 1953)
# ================================================================================
# Oklahoma City v. Stewart, 8 P.2d 30 (Okla. 1932)
# ================================================================================
# Barrett v. University of Colorado Health Sciences Center, 61 U.S.L.W. 2579 (Colo. Ct. App. 1993)
# ================================================================================
# McIntyre v. Jones, 194 P.3d 519 (Colo. Ct. App. 2008)
# ================================================================================
# City of Cincinnati v. Discovery Network, Inc., 507 U.S. 410
# ================================================================================
# State v. James-Buhl, 415 P.3d 234 (Wash. 2018)
# ================================================================================
# Chevron Corp. v. Berlinger, 629 F.3d 297 (2d Cir. 2011)
# ================================================================================
# People v. Combest, 831 N.E.2d 407 (NY 2005)
# ================================================================================
# Silkwood v. Kerr-McGee Corp., 464 U.S. 238
# ================================================================================
# Simon v. Northwestern University, 321 F.R.D. 328 (N.D. Ill. 2017)
# ================================================================================
# Estate of Esther Klieman v. Palestinian Authority, Civil Action No. 2004-1173 (D.D.C. 2012)
# ================================================================================
# John B. Clyburn v. News World Communications, Inc., and One-Up Enterprises, Inc., 903 F.2d 29 (D.C. Cir. 1990)
# ================================================================================
# Zerilli v. Smith, 656 F.2d 705 (D.C. Cir. 1981)
# ================================================================================
# Carey v. Hume, 390 F. Supp. 1026 (D.D.C. 1975)
# ================================================================================
# Andy Thayer v. Ralph Chiczewski, 10-1974 (7th Cir. 2012)
# ================================================================================
# Shoen v. Shoen, 804 P.2d 787 (Ariz. Ct. App. 1990)
# ================================================================================
# Cincinnati v. State, 2024 Ohio 2425
# ================================================================================
# LaPorte v. State, 840 S.W.2d 412 (Tex. Crim. App. 1992)
# ================================================================================
# Jeremy Migut v. Sean Flynn, 131 F. App'x 262 (11th Cir. 2005)
# ================================================================================
# Sims v. Majors, 344 S.E.2d 501 (Ga. Ct. App. 1986)
# ================================================================================
# Tyler v. Lincoln, 527 S.E.2d 180 (Ga. 2000)
# ================================================================================
# State v. Cohen, 396 N.E.2d 235 (Ohio Ct. App. 1978)
# ================================================================================
# Adams v. City of New Orleans, Louisiana, 208 F. Supp. 427 (E.D. La. 1962)
# ================================================================================
# Connick v. Thompson, 563 U.S. 51
# ================================================================================
# Bernard v. Connick, 954 F.2d 721 (5th Cir. 1992)
# ================================================================================
# Brady v. Maryland, 373 U.S. 83
# ================================================================================
# Giglio v. United States, 405 U.S. 150
# ================================================================================
# Dino Cinel v. Harry F. Connick, Individually and as District Attorney for the Parish of Orleans, State of Louisiana, 15 F.3d 1338 (5th Cir. 1994)
# ================================================================================
# Smith v. United States, 360 U.S. 1
# ================================================================================
# Simpson v. Simpson, 4 P.2d 345 (Idaho 1931)
# ================================================================================
# State v. Reeves, 670 N.W.2d 199 (Iowa 2003)
# ================================================================================
# Sandra Boddie v. American Broadcasting Companies, Inc. Geraldo Rivera Charles C. Thompson and Maravilla Production Company, Inc., 731 F.2d 333 (6th Cir. 1984)
# ================================================================================
# State v. Conn, 669 P.2d 581 (Ariz. 1983)
# ================================================================================
# State Ex Rel. Womack v. Blackburn, 393 So. 2d 1216 (La. 1981)
# ================================================================================
# Harrington v. Abshire, 732 So. 2d 677 (La. Ct. App. 1999)
# ================================================================================
# Lavergne v. Lawtell Gravity Drainage Dist. No. 11, 562 So. 2d 1013 (La. Ct. App. 1990)
# ================================================================================
# Bayou Fleet Partnership v. Clulee, 150 So. 3d 329 (La. Ct. App. 2014)
# ================================================================================
# Wendorf v. Corley, 394 So. 2d 1252 (La. Ct. App. 1980)
# ================================================================================
# Branzburg v. Hayes, 408 U.S. 665
# ================================================================================
# State v. Knutson, 222 N.W. 277 (Minn. 1928)
# ================================================================================
# State v. Turner, 556 S.W.2d 563 (Tex. 1977)
# ================================================================================
# Weinberger v. Maplewood Review, 668 N.W.2d 667 (Minn. 2003)
# ================================================================================
# Range Development Company of Chisholm v. Star Tribune, Paul McEnroe, 885 N.W.2d 500 (Minn. Ct. App. 2016)
# ================================================================================
# State v. Berglund, 829 P.2d 247 (Wash. Ct. App. 1992)
# ================================================================================
# Zick v. City of Maplewood, 50 F. App'x 805 (8th Cir. 2002)
# ================================================================================
# Bredemus v. International Paper Co., 252 F.R.D. 529 (D. Minnesota 2008)
# ================================================================================
# Bauer v. Gannett Co., Inc.(KARE 11), 557 N.W.2d 608 (Minn. Ct. App. 1997)
# ================================================================================
# Franchise Tax Bd. of Cal. v. Hyatt, 538 U.S. 488
# ================================================================================
# Flowers v. Carville, 112 F. Supp. 2d 1202 (D. Nev. 2000)
# ================================================================================
# Montesano v. Donrey Media Group, 668 P.2d 1081 (Nev. 1983)
# ================================================================================
# Kuhn v. Account Control Technology, Inc., 865 F. Supp. 1443 (D. Nev. 1994)
# ================================================================================
# Andrew P. Lane v. Allstate Insurance Company, 746 F.2d 1444 (11th Cir. 1984)
# ================================================================================
# Parkinson v. Winniman, 344 P.2d 677 (Nev. 1959)
# ================================================================================
# United States v. Burke, 504 U.S. 229
# ================================================================================
# United States v. Otis Cutler, Jr., 36 F.3d 406 (4th Cir. 1994)
# ================================================================================
# United States v. Treacy, 639 F.3d 32 (2d Cir. 2011)
# ================================================================================
# Holmes v. Winter, 110 A.D.3d 134 (N.Y. App. Div. 2013)
# ================================================================================
# People v. Hendrix, 941 P.2d 64 (Cal. 1997)
# ================================================================================
# Chanko v. American Broadcasting Companies, Inc., 49 N.E.3d 1171 (NY 2016)
# ================================================================================
# Doe v. American Broadcasting Companies, Inc., 152 A.D.2d 482 (N.Y. App. Div. 1989)
# ================================================================================
# Nader v. General Motors Corp., 255 N.E.2d 765 (NY 1970)
# ================================================================================
# Foster v. Svenson, 128 A.D.3d 150 (N.Y. App. Div. 2015)
# ================================================================================
# Berger v. Hanlon, 129 F.3d 505 (9th Cir. 1997)
# ================================================================================
# Barrett v. Outlet Broadcasting, Inc., 22 F. Supp. 2d 726 (S.D. Ohio 1997)
# ================================================================================
# Ayeni Ex Rel. Ayeni v. CBS Inc., 848 F. Supp. 362 (E.D.N.Y 1994)
# ================================================================================
# Wilson v. Layne, 96-1185 (4th Cir. 1999)
# ================================================================================
# Sandra C. Parker v. Rodney Boyer, 93 F.3d 445 (8th Cir. 1996)
# ================================================================================
# Glenda Brunette v. Humane Society of Ventura County, a Non-Profit Corporation the Ojai Publishing Company, Inc., D/B/A the Ojai Valley News, a Corporation Tim Dewar Jolene Opinion Hoffman Robert Jeffrey Hoffman Shawna Boatman Tim Cozatt, 294 F.3d 1205 (9th Cir. 2002)
# ================================================================================
# Robinson v. City and County of Denver, 30 P.3d 677 (Colo. Ct. App. 2000)
# ================================================================================
# Abraham v. Greer, 509 S.W.3d 609 (Tex. App. 2016)
# ================================================================================
# Gattoni v. Tibi, LLC, 254 F. Supp. 3d 659 (S.D.N.Y. 2017)
# ================================================================================
# Ferdman v. CBS Interactive Inc., 342 F. Supp. 3d 515 (S.D. Ill. 2018)
# ================================================================================
# ================================================================================
# Lopez v. Triangle Communications, Inc., 70 A.D.2d 359 (N.Y. App. Div. 1979)
# ================================================================================
# Stern v. Delphi Internet Services Corp., 165 Misc. 2d 21 (N.Y. Sup. Ct. 1995)
# ================================================================================
# Namath v. Sports Illustrated, 48 A.D.2d 487 (N.Y. App. Div. 1975)
# ================================================================================
# Murray v. New York Magazine Co., 267 N.E.2d 256 (NY 1971)
# ================================================================================
# Brinkley v. Casablancas, 80 A.D.2d 428 (N.Y. App. Div. 1981)
# ================================================================================
# Cohen v. Hallmark Cards, Inc., 70 A.D.2d 509 (N.Y. App. Div. 1979)
# ================================================================================
# Roe v. Wade, 410 U.S. 113
# ================================================================================
# Whalen v. Roe, 429 U.S. 589
# ================================================================================
# Griswold v. Connecticut, 381 U.S. 479
# ================================================================================
# Paul v. Davis, 424 U.S. 693
# ================================================================================
# Anderson v. Liberty Lobby, Inc., 477 U.S. 242
# ================================================================================
# Jackie Collins Lerman v. Flynt Distributing Co., Inc., 745 F.2d 123 (2d Cir. 1984)
# ================================================================================
# Davis v. High Society Magazine, Inc., 90 A.D.2d 374 (N.Y. App. Div. 1982)
# ================================================================================
# Paulsen v. Personality Posters, Inc., 59 Misc. 2d 444 (N.Y. Sup. Ct. 1968)
# ================================================================================
# Booth v. Curtis Publishing Co., 15 A.D.2d 343 (N.Y. App. Div. 1962)
# ================================================================================
# Zacchini v. Scripps-Howard Broadcasting Co., 433 U.S. 562
# ================================================================================
# Galella v. Onassis, 353 F. Supp. 196 (S.D.N.Y. 1972)
# ================================================================================
#
# Total cases extracted: 198

# %% [markdown]
# Lets Extract All the Cases Cited by the LLM

# %%
import re

# File path
file_path = "Model-output.txt"

# Simple regex to detect court case citations (e.g., "X v. Y")
case_pattern = re.compile(r'\b[A-Z][a-zA-Z]+ v\. [A-Z][a-zA-Z]+(?:, [\w\s.()]+)?')

# Store matched court case names only
court_cases = []

# Read file line by line
with open(file_path, "r", encoding="utf-8") as file:
    for line in file:  # Read each line separately
        matches = case_pattern.findall(line)  # Find all matches in the line
        court_cases.extend(matches)  # Add matches to the list

# Print only the extracted court case names
for case in court_cases:
    print(case)
# Out:
# Hurwitz v. United
# Messenger v. Gruner
# Andrea v. Fakename, 972 F.Supp. 154
# Gautier v. Pro
# Weil v. Johnson, Index No. 119431
# Piskac v. Shapiro, 230 Conn. 345 (2025). If the exhibition was advertised
# Lemerond v. Twentieth
# Delan v. CBS, Inc.
# Finger v. Omni
# Arrington v. New
# Candelaria v. Spurlock, the plaintiff appeared briefly in the documentary Super Size Me. The plaintiff did not allege that his appearance was for advertising or trade. The plaintiff did
# Spurlock v. Candelaria, 08 Civ. 1830 (BMC) (RER)

# %%
import spacy

# Load SpaCy English model
nlp = spacy.load("en_core_web_sm")

# Read file
file_path = "combined-text.txt"

cases = []
cases_headers = []
current_case = []
blank_line_count = 0
line_num = 0

# Function to detect case headers using SpaCy
def is_case_header(line):
    doc = nlp(line.strip())  # Process line with SpaCy
    if "v." in line:  # Basic filter to ensure it looks like a case name
        for ent in doc.ents:
            if ent.label_ == "LAW":  # SpaCy's legal entity recognition (if available)
                return True
        # If no "LAW" entity, fall back on simple pattern match
        return doc[0].is_title and "v." in line
    return False

with open(file_path, "r", encoding="utf-8") as file:
    for line in file:
        line_num += 1

        if line.strip() == "":  # Blank line detected
            blank_line_count += 1
            continue

        # Detect new case start
        if blank_line_count >= 2 and is_case_header(line) or line_num == 1:
            # Store previous case
            if current_case:
                cases.append("\n".join(current_case))

            # Start new case
            current_case = [line.strip()]
            cases_headers.append(line.strip())

        else:
            # Continue collecting lines for the current case
            current_case.append(line.strip())

        blank_line_count = 0  # Reset blank line counter

# Add the last case if the file does not end with a blank line
if current_case:
    cases.append("\n".join(current_case))

# Print extracted case headers
for case in cases_headers:
    print(case)
    print("=" * 80)  # Separator for readability

print(f"\nTotal cases extracted: {len(cases)}")
# Out:
# Burns v. McGraw-Hill Broadcasting Co., Inc., 9 Media L. Rep. (BNA) 1257 (Colo. 1983)
# ================================================================================
# Ken-Do Contracting, L.P. v. F.A. Brown's Construction, LLC D/B/A Brown Construction and Brown's Concrete Construction, 05-19-00228-CV (Tex. App. 2020)
# ================================================================================
# Garden v. Parfumerie Rigaud, Inc., 151 Misc. 692 (N.Y. Sup. Ct. 1933)
# ================================================================================
# Nutrivida, Inc. v. Inmuno Vital, Inc., 46 F. Supp. 2d 1310 (S.D. Fla. 1998)
# ================================================================================
# Gautier v. Pro-Football, Inc., 107 N.E.2d 485 (NY 1952)
# ================================================================================
# Belluomo v. Kake TV & Radio, Inc., 596 P.2d 832 (Kan. Ct. App. 1979)
# ================================================================================
# Michael S. Virgil, AKA Mike Virgil v. Time, Inc., a New York Corporation, 527 F.2d 1122 (9th Cir. 1975)
# ================================================================================
# Nobles v. Cartwright, 659 N.E.2d 1064 (Ind. Ct. App. 1995)
# ================================================================================
# Passalacqua v. Naviant, Inc., 844 So. 2d 792 (Fla. Dist. Ct. App. 2003)
# ================================================================================
# Service Centers of Chicago, Inc. v. Minogue, 535 N.E.2d 1132 (Ill. App. Ct. 1989)
# ================================================================================
# Legal Servicing, LLC v. Lewis, 2021 NY Slip Op 06088
# ================================================================================
# National Abortion Federation v. Center for Medical Progress, 926 F.3d 534 (9th Cir. 2019)
# ================================================================================
# Anonsen v. Donahue, 857 S.W.2d 700 (Tex. App. 1993)
# ================================================================================
# Kenol v. Nelson, 181 A.D.2d 863 (N.Y. App. Div. 1992)
# ================================================================================
# Keyzer v. Amerlink, Ltd., 654 S.E.2d 833 (N.C. Ct. App. 2008)
# ================================================================================
# Miller v. Brooks, 47 S.E. 646 (Ga. 1904)
# ================================================================================
# Miami Herald Pub. Co. v. Ane, 10 Media L. Rep. (BNA) 2383 (Fla. 1984)
# ================================================================================
# Della-Donna v. Gore Newspapers Co., 489 So. 2d 72 (Fla. Dist. Ct. App. 1986)
# ================================================================================
# Dockery v. Florida Democratic Party, 799 So. 2d 291 (Fla. Dist. Ct. App. 2001)
# ================================================================================
# Silvester v. American Broadcasting Companies, Inc., 650 F. Supp. 766 (S.D. Fla. 1986)
# ================================================================================
# Gubarev v. Buzzfeed, Inc., 365 F. Supp. 3d 1250 (S.D. Fla. 2019)
# ================================================================================
# Saro Corp. v. Waterman Broadcasting Corp., 595 So. 2d 87 (Fla. Dist. Ct. App. 1992)
# ================================================================================
# From v. Tallahassee Democrat, Inc., 7 Media L. Rep. (BNA) 1811 (Fla. Dist. Ct. App. 1981)
# ================================================================================
# Time, Inc. v. Firestone, 424 U.S. 448
# ================================================================================
# Jews for Jesus, Inc. v. Rapp, 997 So. 2d 1098 (Fla. 2008)
# ================================================================================
# Southern Air Transport, Inc. v. Post-Newsweek Stations, Florida, Inc., 568 So. 2d 927 (Fla. Dist. Ct. App. 1990)
# ================================================================================
# Border Collie Rescue, Inc. v. Ryan, 418 F. Supp. 2d 1330 (M.D. Fla. 2006)
# ================================================================================
# Uranga v. Federated Publications, Inc., 67 P.3d 29 (Idaho 2003)
# ================================================================================
# Steele v. Spokesman-Review, 61 P.3d 606 (Idaho 2002)
# ================================================================================
# State v. PENTICO, 265 P.3d 519 (Idaho Ct. App. 2011)
# ================================================================================
# Keyzer v. Amerlink, Ltd., 654 S.E.2d 833 (N.C. Ct. App. 2008)
# ================================================================================
# Broughton v. McClatchy Newspapers, Inc., 588 S.E.2d 20 (N.C. Ct. App. 2003)
# ================================================================================
# Food Lion, Inc. v. Capital Cities/ABC, Inc., 194 F.3d 505 (4th Cir. 1999)
# ================================================================================
# Magenis v. Fisher Broadcasting, Inc., 798 P.2d 1106 (Or. Ct. App. 1990)
# ================================================================================
# State v. Knobel, 777 P.2d 985 (Or. Ct. App. 1989)
# ================================================================================
# Mark v. Seattle Times, 635 P.2d 1081 (Wash. 1981)
# ================================================================================
# Phillips v. KIRO-TV, Inc., 817 F. Supp. 2d 1317 (W.D. Wash. 2011)
# ================================================================================
# Gonzaga University v. Doe, 536 U.S. 273
# ================================================================================
# Nieves v. Home Box Office, Inc., 30 A.D.3d 1143 (N.Y. App. Div. 2006)
# ================================================================================
# Reesman v. Highfill, 965 P.2d 1030 (Or. 1998)
# ================================================================================
# Marleau v. Truck Insurance Exchange, 37 P.3d 148 (Or. 2001)
# ================================================================================
# Tollefson v. Price, 430 P.2d 990 (Or. 1967)
# ================================================================================
# Dean v. Guard Publishing Co., 744 P.2d 1296 (Or. Ct. App. 1987)
# ================================================================================
# Robillard v. Opal Labs, Inc., 337 F. Supp. 3d 962 (D. Or. 2018)
# ================================================================================
# Magenis v. Fisher Broadcasting, Inc., 798 P.2d 1106 (Or. Ct. App. 1990)
# ================================================================================
# Miller v. American Sports Co., Inc., 467 N.W.2d 653 (Neb. 1991)
# ================================================================================
# Elbert v. Young, 312 Neb. 58 (Neb. 2022)
# ================================================================================
# Baxter Berry v. National Broadcasting Company, Inc., 480 F.2d 428 (8th Cir. 1973)
# ================================================================================
# New York Times Co. v. Sullivan, 376 U.S. 254
# ================================================================================
# Kaiser v. Western R/C Flyers, Inc., 477 N.W.2d 557 (Neb. 1991)
# ================================================================================
# Turner v. Welliver, 411 N.W.2d 298 (Neb. 1987)
# ================================================================================
# Moats v. Republican Party of Nebraska, 565 U.S. 882
# ================================================================================
# Funk v. Lincoln-Lancaster Cty. Crime Stoppers, 885 N.W.2d 1 (Neb. 2016)
# ================================================================================
# State v. Biernacki, 465 N.W.2d 732 (Neb. 1991)
# ================================================================================
# State v. Rudnick, 341 P.3d 211 (Or. Ct. App. 2014)
# ================================================================================
# Pargas of Longview, Inc. v. Jones, 573 S.W.2d 571 (Tex. App. 1978)
# ================================================================================
# Michael T. v. Crouch, 344 F. Supp. 3d 856 ( 2018)
# ================================================================================
# Howell v. New York Post Co., 81 N.Y.2d 115 (NY 1993)
# ================================================================================
# Beverley v. WOMEN'S MED CTR., 78 N.Y.2d 745 (NY 1991)
# ================================================================================
# Thompson v. Close-Up, Inc., 277 A.D.2d 848 (N.Y. App. Div. 1950)
# ================================================================================
# Messenger v. Gruner + Jahr Printing & Publishing, 727 N.E.2d 549 (NY 2000)
# ================================================================================
# J.H. Desnick, M.D., Eye Services, Ltd. v. American Broadcasting Companies, Inc., Jon Entine, and Sam Donaldson, 233 F.3d 514 (7th Cir. 2000)
# ================================================================================
# Commonwealth v. Alleyne, 405 N.E.2d 171 (Mass. App. Ct. 1980)
# ================================================================================
# Jackson v. Commonwealth, 287 S.W. 17 (Ky. Ct. App. 1926)
# ================================================================================
# Commonwealth v. Hyde, 88 Mass. App. Ct. 761 (Mass. App. Ct. 2015)
# ================================================================================
# Project Veritas Action Fund v. Rollins, 19-1586P (1st Cir. 2020)
# ================================================================================
# Martin v. Rollins, Inc., 231 S.E.2d 751 (Ga. 1977)
# ================================================================================
# Bartnicki v. Vopper, 532 U.S. 514
# ================================================================================
# Ayash v. Dana-Farber Cancer Institute, 443 Mass. 367 (Mass. 2005)
# ================================================================================
# Ferrell v. Southern Nevada Off-Road Enthusiasts, Ltd., 147 Cal. App. 3d 309 (Cal. Ct. App. 1983)
# ================================================================================
# Hohe v. San Diego Unified School District, 224 Cal. App. 3d 1559 (Cal. Ct. App. 1990)
# ================================================================================
# Johnston v. Weil, 946 N.E.2d 329 (Ill. 2011)
# ================================================================================
# Facenda v. N.F.L. Films, Inc., 542 F.3d 1007 (3rd Cir. 2008)
# ================================================================================
# Ahn v. Midway Manufacturing Co., 965 F. Supp. 1134 (N.D. Ill. 1997)
# ================================================================================
# Kyser-Smith v. Upscale Communications, Inc., 873 F. Supp. 1519 (M.D. Ala. 1995)
# ================================================================================
# Powers v. United States, 223 U.S. 303
# ================================================================================
# Michael B. Price v. Time, Inc., 425 F.3d 1292 (11th Cir. 2005)
# ================================================================================
# Cooper v. Long, 244 P. 167 (Okla. 1926)
# ================================================================================
# Pinkard v. Johnson, 118 F.R.D. 517 (M.D. Ala. 1987)
# ================================================================================
# Capers v. State, 678 So. 2d 330 (Fla. 1996)
# ================================================================================
# Wilson v. Interlake Steel Co., 649 P.2d 922 (Cal. 1982)
# ================================================================================
# Ralphs Grocery Co. v. Victory Consultants, Inc., D070804A (Cal. Ct. App. 2018)
# ================================================================================
# Denver Publishing Co. v. Bueno, 54 P.3d 893 (Colo. 2002)
# ================================================================================
# Doe v. High-Tech Institute, Inc., 972 P.2d 1060 (Colo. Ct. App. 1998)
# ================================================================================
# Bernard v. Connick, 954 F.2d 721 (5th Cir. 1992)
# ================================================================================
# Brady v. Maryland, 373 U.S. 83
# ================================================================================
# Giglio v. United States, 405 U.S. 150
# ================================================================================
# Dino Cinel v. Harry F. Connick, Individually and as District Attorney for the Parish of Orleans, State of Louisiana, 15 F.3d 1338 (5th Cir. 1994)
# ================================================================================
# Smith v. United States, 360 U.S. 1
# ================================================================================
# Simpson v. Simpson, 4 P.2d 345 (Idaho 1931)
# ================================================================================
# State v. Reeves, 670 N.W.2d 199 (Iowa 2003)
# ================================================================================
# Sandra Boddie v. American Broadcasting Companies, Inc. Geraldo Rivera Charles C. Thompson and Maravilla Production Company, Inc., 731 F.2d 333 (6th Cir. 1984)
# ================================================================================
# State v. Conn, 669 P.2d 581 (Ariz. 1983)
# ================================================================================
# State Ex Rel. Womack v. Blackburn, 393 So. 2d 1216 (La. 1981)
# ================================================================================
# Harrington v. Abshire, 732 So. 2d 677 (La. Ct. App. 1999)
# ================================================================================
# Lavergne v. Lawtell Gravity Drainage Dist. No. 11, 562 So. 2d 1013 (La. Ct. App. 1990)
# ================================================================================
# General Acc. F. & L. Assur. Corp. v. Humble Oil & R. Co., 243 So. 2d 865 (La. Ct. App. 1971)
# ================================================================================
# Bayou Fleet Partnership v. Clulee, 150 So. 3d 329 (La. Ct. App. 2014)
# ================================================================================
# Wendorf v. Corley, 394 So. 2d 1252 (La. Ct. App. 1980)
# ================================================================================
# Branzburg v. Hayes, 408 U.S. 665
# ================================================================================
# State v. Knutson, 222 N.W. 277 (Minn. 1928)
# ================================================================================
# State v. Turner, 556 S.W.2d 563 (Tex. 1977)
# ================================================================================
# Weinberger v. Maplewood Review, 668 N.W.2d 667 (Minn. 2003)
# ================================================================================
# Range Development Company of Chisholm v. Star Tribune, Paul McEnroe, 885 N.W.2d 500 (Minn. Ct. App. 2016)
# ================================================================================
# State v. Berglund, 829 P.2d 247 (Wash. Ct. App. 1992)
# ================================================================================
# Zick v. City of Maplewood, 50 F. App'x 805 (8th Cir. 2002)
# ================================================================================
# Bredemus v. International Paper Co., 252 F.R.D. 529 (D. Minnesota 2008)
# ================================================================================
# Bauer v. Gannett Co., Inc.(KARE 11), 557 N.W.2d 608 (Minn. Ct. App. 1997)
# ================================================================================
# Bobby Berosini, Ltd. v. People for the Ethical Treatment of Animals, 971 P.2d 383 (Nev. 1998)
# ================================================================================
# Franchise Tax Bd. of Cal. v. Hyatt, 538 U.S. 488
# ================================================================================
# Flowers v. Carville, 112 F. Supp. 2d 1202 (D. Nev. 2000)
# ================================================================================
# Montesano v. Donrey Media Group, 668 P.2d 1081 (Nev. 1983)
# ================================================================================
# Kuhn v. Account Control Technology, Inc., 865 F. Supp. 1443 (D. Nev. 1994)
# ================================================================================
# M & R Inv. Co., Inc. v. Mandarino, 748 P.2d 488 (Nev. 1987)
# ================================================================================
# Andrew P. Lane v. Allstate Insurance Company, 746 F.2d 1444 (11th Cir. 1984)
# ================================================================================
# Parkinson v. Winniman, 344 P.2d 677 (Nev. 1959)
# ================================================================================
# United States v. Burke, 504 U.S. 229
# ================================================================================
# ================================================================================
# Brinkley v. Casablancas, 80 A.D.2d 428 (N.Y. App. Div. 1981)
# ================================================================================
# Cohen v. Hallmark Cards, Inc., 70 A.D.2d 509 (N.Y. App. Div. 1979)
# ================================================================================
# Roe v. Wade, 410 U.S. 113
# ================================================================================
# Whalen v. Roe, 429 U.S. 589
# ================================================================================
# Griswold v. Connecticut, 381 U.S. 479
# ================================================================================
# Paul v. Davis, 424 U.S. 693
# ================================================================================
# Anderson v. Liberty Lobby, Inc., 477 U.S. 242
# ================================================================================
# R.C. Bigelow, Inc. v. Unilever N.V., 689 F. Supp. 76 (D. Conn. 1988)
# ================================================================================
# Jackie Collins Lerman v. Flynt Distributing Co., Inc., 745 F.2d 123 (2d Cir. 1984)
# ================================================================================
# Davis v. High Society Magazine, Inc., 90 A.D.2d 374 (N.Y. App. Div. 1982)
# ================================================================================
# Factors Etc., Inc. v. Pro Arts, Inc., 562 F. Supp. 304 (S.D.N.Y. 1983)
# ================================================================================
# Paulsen v. Personality Posters, Inc., 59 Misc. 2d 444 (N.Y. Sup. Ct. 1968)
# ================================================================================
# Booth v. Curtis Publishing Co., 15 A.D.2d 343 (N.Y. App. Div. 1962)
# ================================================================================
# Zacchini v. Scripps-Howard Broadcasting Co., 433 U.S. 562
# ================================================================================
# Galella v. Onassis, 353 F. Supp. 196 (S.D.N.Y. 1972)
# ================================================================================
#
# Total cases extracted: 222

# %%
import spacy

# Load SpaCy English model
nlp = spacy.load("en_core_web_sm")

# File path
file_path = "Model-output.txt"

# Store extracted case citations
court_cases = set()  # Using a set to avoid duplicates

# Read and process file
with open(file_path, "r", encoding="utf-8") as file:
    text = file.read()  # Read the entire file at once for better context analysis

# Process text with SpaCy
doc = nlp(text)

# Extract case citations
for sentence in doc.sents:  # Iterate through detected sentences
    if "v." in sentence.text:  # Basic filter to reduce false positives
        court_cases.add(sentence.text.strip())

# Print extracted case citations
for case in court_cases:
    print(case)
    print("=" * 80)  # Separator for readability

print(f"\nTotal court cases extracted: {len(court_cases)}")
# Out:
# See D’Andrea v. Fakename, 972 F.Supp.
# ================================================================================
# Piskac v. Shapiro, 230 Conn. 345 (2025).
# ================================================================================
# L. Rev. 383, 402-03).
# ================================================================================
# In Candelaria v. Spurlock, the plaintiff appeared briefly in the documentary Super Size Me.
# ================================================================================
# See Gautier v. Pro-Football, Inc., 304 N.Y. 354, 359, 107 N.E.2d 485 (1952) (holding that a football player’s image was not used for trade or advertising when it appeared in a newsreel of a football game).
# ================================================================================
# See Spurlock v. Candelaria, 08 Civ. 1830 (BMC) (RER), E.D.N.Y. Jul. 3, 2008).
# ================================================================================
# Arrington v. New York Times Co., 55 N.Y.22d 433, 440, 449 N.Y.S.22d 941, 944, 434 N.E.22d 1319, 1322 (1982).
# ================================================================================
# Lemerond v. Twentieth Century Fox Film Corp.,  564 F.Supp.2d 315, 323 (S.D.N.Y.), aff'd sub nom.
# ================================================================================
# Delan by Delan v. CBS, Inc., 91 A.D.3d 255, 458 N.Y.S.23d 608 (2d Dep’t 2013).
# ================================================================================
# Finger v. Omni Publs.
# ================================================================================
# See Weil v. Johnson, Index No. 119431/02, 2002 WL 31972157, *4-5 (
# ================================================================================
# See Hurwitz v. United States, 884 F.2d 684, 687 (2d Cir. 1989);Messenger v. Gruner Key Symbol Jahr Printing and Publ’g, 94 N.Y.2d 436, 441, 706 N.Y.S.2d 52, 54 (2000).
# ================================================================================
#
# Total court cases extracted: 12

# %% [markdown]
# COMBINATION STRUCTURE

# %%
# Extract cases from both files
case_database = cases_headers
cited_cases = court_cases

print(f"Total real cases: {len(case_database)}, Total cited cases: {len(cited_cases)}")
# Out:
# Total real cases: 222, Total cited cases: 12

# %%
from sentence_transformers import SentenceTransformer

# Load embedding model
model = SentenceTransformer("all-MiniLM-L6-v2")

# Generate embeddings
case_embeddings = {case: model.encode(case) for case in case_database}
cited_embeddings = {case: model.encode(case) for case in cited_cases}
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl (30.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 32.6 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.10.0

# %%
import faiss
import numpy as np

# Get embedding dimension
dim = len(next(iter(case_embeddings.values())))

# Create FAISS index
index = faiss.IndexFlatL2(dim)

# Convert case embeddings to numpy arrays
case_names = list(case_embeddings.keys())
case_vectors = np.array(list(case_embeddings.values()), dtype=np.float32)

# Add embeddings to FAISS index
index.add(case_vectors)

# Function to find closest match
def find_nearest_case(query_case):
    """Find the closest matching case in the FAISS index."""
    query_vec = np.array([cited_embeddings[query_case]], dtype=np.float32)
    distances, indices = index.search(query_vec, 1)  # Search for nearest neighbor
    return case_names[indices[0][0]], distances[0][0]  # Return closest case and distance

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Detect nonexistent cases
nonexistent_cases = [case for case in cited_cases if case not in case_database]

# Detect misinterpreted cases
misinterpreted_cases = []
for case in cited_cases:
    if case in case_database:  # Only check for misinterpretation in valid cases
        closest_case, distance = find_nearest_case(case)
        similarity = cosine_similarity([cited_embeddings[case]], [case_embeddings[closest_case]])[0][0]
        if similarity < 0.7:  # Threshold for misinterpretation
            misinterpreted_cases.append((case, similarity))

# Print results
print(f"Nonexistent cases: {nonexistent_cases}")
print(f"Misinterpreted cases: {misinterpreted_cases}")
# Out:
# Nonexistent cases: ['See D’Andrea v. Fakename, 972 F.Supp.', 'Piskac v. Shapiro, 230 Conn. 345 (2025).', 'L. Rev. 383, 402-03).', 'In Candelaria v. Spurlock, the plaintiff appeared briefly in the documentary Super Size Me.', 'See Gautier v. Pro-Football, Inc., 304 N.Y. 354, 359, 107 N.E.2d 485 (1952) (holding that a football player’s image was not used for trade or advertising when it appeared in a newsreel of a football game).', 'See Spurlock v. Candelaria, 08 Civ. 1830 (BMC) (RER), E.D.N.Y. Jul. 3, 2008).', 'Arrington v. New York Times Co., 55 N.Y.22d 433, 440, 449 N.Y.S.22d 941, 944, 434 N.E.22d 1319, 1322 (1982).', "Lemerond v. Twentieth Century Fox Film Corp.,  564 F.Supp.2d 315, 323 (S.D.N.Y.), aff'd sub nom.", 'Delan by Delan v. CBS, Inc., 91 A.D.3d 255, 458 N.Y.S.23d 608 (2d Dep’t 2013).', 'Finger v. Omni Publs.', 'See Weil v. Johnson, Index No. 119431/02, 2002 WL 31972157, *4-5 (', 'See Hurwitz v. United States, 884 F.2d 684, 687 (2d Cir. 1989);Messenger v. Gruner Key Symbol Jahr Printing and Publ’g, 94 N.Y.2d 436, 441, 706 N.Y.S.2d 52, 54 (2000).']
# Misinterpreted cases: []
